# %%
# !pip index versions faiss-cpu
# Out:
# WARNING: pip index is currently an experimental command. It may be removed/changed in a future release without prior warning.
# faiss-cpu (1.13.0)
# Available versions: 1.13.0, 1.12.0, 1.11.0.post1, 1.11.0, 1.10.0, 1.9.0.post1, 1.9.0, 1.8.0.post1, 1.8.0

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 103.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)

# %%
import json
import numpy as np
import faiss
from PIL import Image
import requests
from io import BytesIO
import torch
from transformers import CLIPProcessor, CLIPModel

# %%
# Load dữ liệu từ file JSON
with open('/content/sample_data/Female_updated.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

products = data['products']

# %%
# Load model FashionCLIP
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained("patrickjohncyh/fashion-clip").to(device)
processor = CLIPProcessor.from_pretrained("patrickjohncyh/fashion-clip")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
def get_image_embedding(image_url):
    """Lấy embedding từ ảnh"""
    try:
        response = requests.get(image_url)
        image = Image.open(BytesIO(response.content))
        inputs = processor(images=image, return_tensors="pt", padding=True).to(device)
        with torch.no_grad():
            image_features = model.get_image_features(**inputs)
        return image_features.cpu().numpy().flatten()
    except Exception as e:
        print(f"Lỗi khi xử lý ảnh {image_url}: {str(e)}")
        return None

def truncate_text(text, max_tokens=75):
    """Cắt ngắn text để phù hợp với giới hạn token của model"""
    tokens = processor.tokenizer.encode(text)
    if len(tokens) > max_tokens:
        tokens = tokens[:max_tokens]
        # Decode lại tokens thành text (bỏ token đặc biệt ở đầu và cuối)
        truncated_text = processor.tokenizer.decode(tokens, skip_special_tokens=True)
        return truncated_text
    return text

def get_text_embedding(text):
    """Lấy embedding từ text"""
    try:
        # Cắt ngắn text nếu cần
        truncated_text = truncate_text(text)

        inputs = processor(text=truncated_text, return_tensors="pt", padding=True, truncation=True, max_length=77).to(device)
        with torch.no_grad():
            text_features = model.get_text_features(**inputs)
        return text_features.cpu().numpy().flatten()
    except Exception as e:
        print(f"Lỗi khi xử lý text: {str(e)}")
        print(f"Text gây lỗi (đã cắt ngắn): {truncated_text[:100]}...")
        return None

# %%
embeddings = []
metadata = []
failed_products = []

for i, product in enumerate(products):
    print(f"Đang xử lý sản phẩm {i+1}/{len(products)}")

    # Kết hợp các trường text một cách thông minh, ưu tiên thông tin quan trọng
    title = product.get('pdp_title_value', '')
    desc = product.get('pdp_desc_value', '')
    detail = product.get('detail_description', '')

    # Tạo text tổng hợp, ưu tiên title và mô tả ngắn
    if len(title) > 0:
        combined_text = title
        if len(desc) > 0:
            combined_text += ". " + desc
        # Chỉ thêm detail nếu còn chỗ
        if len(detail) > 0 and len(combined_text) < 200:
            combined_text += ". " + detail
    else:
        combined_text = desc if len(desc) > 0 else detail

    # Lấy embeddings
    image_embedding = get_image_embedding(product['pdp_image_url'])
    text_embedding = get_text_embedding(combined_text)

    if image_embedding is not None and text_embedding is not None:
        # Sử dụng concatenation
        combined_embedding = np.concatenate([image_embedding, text_embedding])
        embeddings.append(combined_embedding)
        metadata.append({
            'pdp_url': product['pdp_url'],
            'pdp_title': product['pdp_title_value'],
            'category': product.get('category', ''),
            'price_sp': product.get('price_sp', ''),
            'image_url': product['pdp_image_url'],
            'combined_text': combined_text[:200] + "..." if len(combined_text) > 200 else combined_text
        })
    else:
        failed_products.append({
            'index': i,
            'title': product.get('pdp_title_value', ''),
            'reason': 'image_embedding' if image_embedding is None else 'text_embedding'
        })

print(f"Xử lý thành công: {len(embeddings)}/{len(products)} sản phẩm")
print(f"Lỗi: {len(failed_products)} sản phẩm")

if len(failed_products) > 0:
    print("Các sản phẩm bị lỗi:")
    for failed in failed_products[:5]:  # Hiển thị 5 sản phẩm lỗi đầu tiên
        print(f"  - Index {failed['index']}: {failed['title']} ({failed['reason']})")

# Chuyển đổi sang numpy array
if len(embeddings) > 0:
    embeddings_array = np.array(embeddings).astype('float32')

    # Tạo FAISS index - dimension sẽ gấp đôi (512 * 2 = 1024)
    dimension = embeddings_array.shape[1]
    print(f"Dimension của embedding: {dimension}")

    index = faiss.IndexFlatIP(dimension)  # Sử dụng inner product cho similarity search

    # Chuẩn hóa vectors để inner product tương đương cosine similarity
    faiss.normalize_L2(embeddings_array)
    index.add(embeddings_array)

    # Lưu index và metadata
    faiss.write_index(index, "fashion_clip_concat_index.faiss")
    with open("metadata_concat.json", "w", encoding='utf-8') as f:
        json.dump(metadata, f, ensure_ascii=False)

    print(f"Đã tạo index với {len(embeddings)} sản phẩm")
    print(f"Kích thước embedding: {dimension}")
    print(f"Kích thước embeddings_array: {embeddings_array.shape}")
else:
    print("Không có sản phẩm nào được xử lý thành công!")
# Out:
# Đang xử lý sản phẩm 1/963
# Đang xử lý sản phẩm 2/963
# Đang xử lý sản phẩm 3/963
# Đang xử lý sản phẩm 4/963
# Đang xử lý sản phẩm 5/963
# Đang xử lý sản phẩm 6/963
# Đang xử lý sản phẩm 7/963
# Đang xử lý sản phẩm 8/963
# Đang xử lý sản phẩm 9/963
# Đang xử lý sản phẩm 10/963
# Đang xử lý sản phẩm 11/963
# Đang xử lý sản phẩm 12/963
# Đang xử lý sản phẩm 13/963
# Đang xử lý sản phẩm 14/963
# Đang xử lý sản phẩm 15/963
# Đang xử lý sản phẩm 16/963
# Đang xử lý sản phẩm 17/963
# Đang xử lý sản phẩm 18/963
# Đang xử lý sản phẩm 19/963
# Đang xử lý sản phẩm 20/963
# Đang xử lý sản phẩm 21/963
# Đang xử lý sản phẩm 22/963
# Đang xử lý sản phẩm 23/963
# Đang xử lý sản phẩm 24/963
# Đang xử lý sản phẩm 25/963
# Đang xử lý sản phẩm 26/963
# Đang xử lý sản phẩm 27/963
# Đang xử lý sản phẩm 28/963
# Đang xử lý sản phẩm 29/963
# Đang xử lý sản phẩm 30/963
# Đang xử lý sản phẩm 31/963
# Đang xử lý sản phẩm 32/963
# Đang xử lý sản phẩm 33/963
# Đang xử lý sản phẩm 34/963
# Đang xử lý sản phẩm 35/963
# Đang xử lý sản phẩm 36/963
# Đang xử lý sản phẩm 37/963
# Đang xử lý sản phẩm 38/963
# Đang xử lý sản phẩm 39/963
# Đang xử lý sản phẩm 40/963
# Đang xử lý sản phẩm 41/963
# Đang xử lý sản phẩm 42/963
# Đang xử lý sản phẩm 43/963
# Đang xử lý sản phẩm 44/963
# Đang xử lý sản phẩm 45/963
# Đang xử lý sản phẩm 46/963
# Đang xử lý sản phẩm 47/963
# Đang xử lý sản phẩm 48/963
# Đang xử lý sản phẩm 49/963
# Đang xử lý sản phẩm 50/963
# Đang xử lý sản phẩm 51/963
# Đang xử lý sản phẩm 52/963
# Đang xử lý sản phẩm 53/963
# Đang xử lý sản phẩm 54/963
# Đang xử lý sản phẩm 55/963
# Đang xử lý sản phẩm 56/963
# Đang xử lý sản phẩm 57/963
# Đang xử lý sản phẩm 58/963
# Đang xử lý sản phẩm 59/963
# Đang xử lý sản phẩm 60/963
# Đang xử lý sản phẩm 61/963
# Đang xử lý sản phẩm 62/963
# Đang xử lý sản phẩm 63/963
# Đang xử lý sản phẩm 64/963
# Đang xử lý sản phẩm 65/963
# Đang xử lý sản phẩm 66/963
# Đang xử lý sản phẩm 67/963
# Đang xử lý sản phẩm 68/963
# Đang xử lý sản phẩm 69/963
# Đang xử lý sản phẩm 70/963
# Đang xử lý sản phẩm 71/963
# Đang xử lý sản phẩm 72/963
# Đang xử lý sản phẩm 73/963
# Đang xử lý sản phẩm 74/963
# Đang xử lý sản phẩm 75/963
# Đang xử lý sản phẩm 76/963
# Đang xử lý sản phẩm 77/963
# Đang xử lý sản phẩm 78/963
# Đang xử lý sản phẩm 79/963
# Đang xử lý sản phẩm 80/963
# Đang xử lý sản phẩm 81/963
# Đang xử lý sản phẩm 82/963
# Đang xử lý sản phẩm 83/963
# Đang xử lý sản phẩm 84/963
# Đang xử lý sản phẩm 85/963
# Đang xử lý sản phẩm 86/963
# Đang xử lý sản phẩm 87/963
# Đang xử lý sản phẩm 88/963
# Đang xử lý sản phẩm 89/963
# Đang xử lý sản phẩm 90/963
# Đang xử lý sản phẩm 91/963
# Đang xử lý sản phẩm 92/963
# Đang xử lý sản phẩm 93/963
# Đang xử lý sản phẩm 94/963
# Đang xử lý sản phẩm 95/963
# Đang xử lý sản phẩm 96/963
# Đang xử lý sản phẩm 97/963
# Đang xử lý sản phẩm 98/963
# Đang xử lý sản phẩm 99/963
# Đang xử lý sản phẩm 100/963
# Đang xử lý sản phẩm 101/963
# Đang xử lý sản phẩm 102/963
# Đang xử lý sản phẩm 103/963
# Đang xử lý sản phẩm 104/963
# Đang xử lý sản phẩm 105/963
# Đang xử lý sản phẩm 106/963
# Đang xử lý sản phẩm 107/963
# Đang xử lý sản phẩm 108/963
# Đang xử lý sản phẩm 109/963
# Đang xử lý sản phẩm 110/963
# Đang xử lý sản phẩm 111/963
# Đang xử lý sản phẩm 112/963
# Đang xử lý sản phẩm 113/963
# Đang xử lý sản phẩm 114/963
# Đang xử lý sản phẩm 115/963
# Đang xử lý sản phẩm 116/963
# Đang xử lý sản phẩm 117/963
# Đang xử lý sản phẩm 118/963
# Đang xử lý sản phẩm 119/963
# Đang xử lý sản phẩm 120/963
# Đang xử lý sản phẩm 121/963
# Đang xử lý sản phẩm 122/963
# Đang xử lý sản phẩm 123/963
# Đang xử lý sản phẩm 124/963
# Đang xử lý sản phẩm 125/963
# Đang xử lý sản phẩm 126/963
# Đang xử lý sản phẩm 127/963
# Đang xử lý sản phẩm 128/963
# Đang xử lý sản phẩm 129/963
# Đang xử lý sản phẩm 130/963
# Đang xử lý sản phẩm 131/963
# Đang xử lý sản phẩm 132/963
# Đang xử lý sản phẩm 133/963
# Đang xử lý sản phẩm 134/963
# Đang xử lý sản phẩm 135/963
# Đang xử lý sản phẩm 136/963
# Đang xử lý sản phẩm 137/963
# Đang xử lý sản phẩm 138/963
# Đang xử lý sản phẩm 139/963
# Đang xử lý sản phẩm 140/963
# Đang xử lý sản phẩm 141/963
# Đang xử lý sản phẩm 142/963
# Đang xử lý sản phẩm 143/963
# Đang xử lý sản phẩm 144/963
# Đang xử lý sản phẩm 145/963
# Đang xử lý sản phẩm 146/963
# Đang xử lý sản phẩm 147/963
# Đang xử lý sản phẩm 148/963
# Đang xử lý sản phẩm 149/963
# Đang xử lý sản phẩm 150/963
# Đang xử lý sản phẩm 151/963
# Đang xử lý sản phẩm 152/963
# Đang xử lý sản phẩm 153/963
# Đang xử lý sản phẩm 154/963
# Đang xử lý sản phẩm 155/963
# Đang xử lý sản phẩm 156/963
# Đang xử lý sản phẩm 157/963
# Đang xử lý sản phẩm 158/963
# Đang xử lý sản phẩm 159/963
# Đang xử lý sản phẩm 160/963
# Đang xử lý sản phẩm 161/963
# Đang xử lý sản phẩm 162/963
# Đang xử lý sản phẩm 163/963
# Đang xử lý sản phẩm 164/963
# Đang xử lý sản phẩm 165/963
# Đang xử lý sản phẩm 166/963
# Đang xử lý sản phẩm 167/963
# Đang xử lý sản phẩm 168/963
# Đang xử lý sản phẩm 169/963
# Đang xử lý sản phẩm 170/963
# Đang xử lý sản phẩm 171/963
# Đang xử lý sản phẩm 172/963
# Đang xử lý sản phẩm 173/963
# Đang xử lý sản phẩm 174/963
# Đang xử lý sản phẩm 175/963
# Đang xử lý sản phẩm 176/963
# Đang xử lý sản phẩm 177/963
# Đang xử lý sản phẩm 178/963
# Đang xử lý sản phẩm 179/963
# Đang xử lý sản phẩm 180/963
# Đang xử lý sản phẩm 181/963
# Đang xử lý sản phẩm 182/963
# Đang xử lý sản phẩm 183/963
# Đang xử lý sản phẩm 184/963
# Đang xử lý sản phẩm 185/963
# Đang xử lý sản phẩm 186/963
# Đang xử lý sản phẩm 187/963
# Đang xử lý sản phẩm 188/963
# Đang xử lý sản phẩm 189/963
# Đang xử lý sản phẩm 190/963
# Đang xử lý sản phẩm 191/963
# Đang xử lý sản phẩm 192/963
# Đang xử lý sản phẩm 193/963
# Đang xử lý sản phẩm 194/963
# Đang xử lý sản phẩm 195/963
# Đang xử lý sản phẩm 196/963
# Đang xử lý sản phẩm 197/963
# Đang xử lý sản phẩm 198/963
# Đang xử lý sản phẩm 199/963
# Đang xử lý sản phẩm 200/963
# Đang xử lý sản phẩm 201/963
# Đang xử lý sản phẩm 202/963
# Đang xử lý sản phẩm 203/963
# Đang xử lý sản phẩm 204/963
# Đang xử lý sản phẩm 205/963
# Đang xử lý sản phẩm 206/963
# Đang xử lý sản phẩm 207/963
# Đang xử lý sản phẩm 208/963
# Đang xử lý sản phẩm 209/963
# Đang xử lý sản phẩm 210/963
# Đang xử lý sản phẩm 211/963
# Đang xử lý sản phẩm 212/963
# Đang xử lý sản phẩm 213/963
# Đang xử lý sản phẩm 214/963
# Đang xử lý sản phẩm 215/963
# Đang xử lý sản phẩm 216/963
# Đang xử lý sản phẩm 217/963
# Đang xử lý sản phẩm 218/963
# Đang xử lý sản phẩm 219/963
# Đang xử lý sản phẩm 220/963
# Đang xử lý sản phẩm 221/963
# Đang xử lý sản phẩm 222/963
# Đang xử lý sản phẩm 223/963
# Đang xử lý sản phẩm 224/963
# Đang xử lý sản phẩm 225/963
# Đang xử lý sản phẩm 226/963
# Đang xử lý sản phẩm 227/963
# Đang xử lý sản phẩm 228/963
# Đang xử lý sản phẩm 229/963
# Đang xử lý sản phẩm 230/963
# Đang xử lý sản phẩm 231/963
# Đang xử lý sản phẩm 232/963
# Đang xử lý sản phẩm 233/963
# Đang xử lý sản phẩm 234/963
# Đang xử lý sản phẩm 235/963
# Đang xử lý sản phẩm 236/963
# Đang xử lý sản phẩm 237/963
# Đang xử lý sản phẩm 238/963
# Đang xử lý sản phẩm 239/963
# Đang xử lý sản phẩm 240/963
# Đang xử lý sản phẩm 241/963
# Đang xử lý sản phẩm 242/963
# Đang xử lý sản phẩm 243/963
# Đang xử lý sản phẩm 244/963
# Đang xử lý sản phẩm 245/963
# Đang xử lý sản phẩm 246/963
# Đang xử lý sản phẩm 247/963
# Đang xử lý sản phẩm 248/963
# Đang xử lý sản phẩm 249/963
# Đang xử lý sản phẩm 250/963
# Đang xử lý sản phẩm 251/963
# Đang xử lý sản phẩm 252/963
# Đang xử lý sản phẩm 253/963
# Đang xử lý sản phẩm 254/963
# Đang xử lý sản phẩm 255/963
# Đang xử lý sản phẩm 256/963
# Đang xử lý sản phẩm 257/963
# Đang xử lý sản phẩm 258/963
# Đang xử lý sản phẩm 259/963
# Đang xử lý sản phẩm 260/963
# Đang xử lý sản phẩm 261/963
# Đang xử lý sản phẩm 262/963
# Đang xử lý sản phẩm 263/963
# Đang xử lý sản phẩm 264/963
# Đang xử lý sản phẩm 265/963
# Đang xử lý sản phẩm 266/963
# Đang xử lý sản phẩm 267/963
# Đang xử lý sản phẩm 268/963
# Đang xử lý sản phẩm 269/963
# Đang xử lý sản phẩm 270/963
# Đang xử lý sản phẩm 271/963
# Đang xử lý sản phẩm 272/963
# Đang xử lý sản phẩm 273/963
# Đang xử lý sản phẩm 274/963
# Đang xử lý sản phẩm 275/963
# Đang xử lý sản phẩm 276/963
# Đang xử lý sản phẩm 277/963
# Đang xử lý sản phẩm 278/963
# Đang xử lý sản phẩm 279/963
# Đang xử lý sản phẩm 280/963
# Đang xử lý sản phẩm 281/963
# Đang xử lý sản phẩm 282/963
# Đang xử lý sản phẩm 283/963
# Đang xử lý sản phẩm 284/963
# Đang xử lý sản phẩm 285/963
# Đang xử lý sản phẩm 286/963
# Đang xử lý sản phẩm 287/963
# Đang xử lý sản phẩm 288/963
# Đang xử lý sản phẩm 289/963
# Đang xử lý sản phẩm 290/963
# Đang xử lý sản phẩm 291/963
# Đang xử lý sản phẩm 292/963
# Đang xử lý sản phẩm 293/963
# Đang xử lý sản phẩm 294/963
# Đang xử lý sản phẩm 295/963
# Đang xử lý sản phẩm 296/963
# Đang xử lý sản phẩm 297/963
# Đang xử lý sản phẩm 298/963
# Đang xử lý sản phẩm 299/963
# Đang xử lý sản phẩm 300/963
# Đang xử lý sản phẩm 301/963
# Đang xử lý sản phẩm 302/963
# Đang xử lý sản phẩm 303/963
# Đang xử lý sản phẩm 304/963
# Đang xử lý sản phẩm 305/963
# Đang xử lý sản phẩm 306/963
# Đang xử lý sản phẩm 307/963
# Đang xử lý sản phẩm 308/963
# Đang xử lý sản phẩm 309/963
# Đang xử lý sản phẩm 310/963
# Đang xử lý sản phẩm 311/963
# Đang xử lý sản phẩm 312/963
# Đang xử lý sản phẩm 313/963
# Đang xử lý sản phẩm 314/963
# Đang xử lý sản phẩm 315/963
# Đang xử lý sản phẩm 316/963
# Đang xử lý sản phẩm 317/963
# Đang xử lý sản phẩm 318/963
# Đang xử lý sản phẩm 319/963
# Đang xử lý sản phẩm 320/963
# Đang xử lý sản phẩm 321/963
# Đang xử lý sản phẩm 322/963
# Đang xử lý sản phẩm 323/963
# Đang xử lý sản phẩm 324/963
# Đang xử lý sản phẩm 325/963
# Đang xử lý sản phẩm 326/963
# Đang xử lý sản phẩm 327/963
# Đang xử lý sản phẩm 328/963
# Đang xử lý sản phẩm 329/963
# Đang xử lý sản phẩm 330/963
# Đang xử lý sản phẩm 331/963
# Đang xử lý sản phẩm 332/963
# Đang xử lý sản phẩm 333/963
# Đang xử lý sản phẩm 334/963
# Đang xử lý sản phẩm 335/963
# Đang xử lý sản phẩm 336/963
# Đang xử lý sản phẩm 337/963
# Đang xử lý sản phẩm 338/963
# Đang xử lý sản phẩm 339/963
# Đang xử lý sản phẩm 340/963
# Đang xử lý sản phẩm 341/963
# Đang xử lý sản phẩm 342/963
# Đang xử lý sản phẩm 343/963
# Đang xử lý sản phẩm 344/963
# Đang xử lý sản phẩm 345/963
# Đang xử lý sản phẩm 346/963
# Đang xử lý sản phẩm 347/963
# Đang xử lý sản phẩm 348/963
# Đang xử lý sản phẩm 349/963
# Đang xử lý sản phẩm 350/963
# Đang xử lý sản phẩm 351/963
# Đang xử lý sản phẩm 352/963
# Đang xử lý sản phẩm 353/963
# Đang xử lý sản phẩm 354/963
# Đang xử lý sản phẩm 355/963
# Đang xử lý sản phẩm 356/963
# Đang xử lý sản phẩm 357/963
# Đang xử lý sản phẩm 358/963
# Đang xử lý sản phẩm 359/963
# Đang xử lý sản phẩm 360/963
# Đang xử lý sản phẩm 361/963
# Đang xử lý sản phẩm 362/963
# Đang xử lý sản phẩm 363/963
# Đang xử lý sản phẩm 364/963
# Đang xử lý sản phẩm 365/963
# Đang xử lý sản phẩm 366/963
# Đang xử lý sản phẩm 367/963
# Đang xử lý sản phẩm 368/963
# Đang xử lý sản phẩm 369/963
# Đang xử lý sản phẩm 370/963
# Đang xử lý sản phẩm 371/963
# Đang xử lý sản phẩm 372/963
# Đang xử lý sản phẩm 373/963
# Đang xử lý sản phẩm 374/963
# Đang xử lý sản phẩm 375/963
# Đang xử lý sản phẩm 376/963
# Đang xử lý sản phẩm 377/963
# Đang xử lý sản phẩm 378/963
# Đang xử lý sản phẩm 379/963
# Đang xử lý sản phẩm 380/963
# Đang xử lý sản phẩm 381/963
# Đang xử lý sản phẩm 382/963
# Đang xử lý sản phẩm 383/963
# Đang xử lý sản phẩm 384/963
# Đang xử lý sản phẩm 385/963
# Đang xử lý sản phẩm 386/963
# Đang xử lý sản phẩm 387/963
# Đang xử lý sản phẩm 388/963
# Đang xử lý sản phẩm 389/963
# Đang xử lý sản phẩm 390/963
# Đang xử lý sản phẩm 391/963
# Đang xử lý sản phẩm 392/963
# Đang xử lý sản phẩm 393/963
# Đang xử lý sản phẩm 394/963
# Đang xử lý sản phẩm 395/963
# Đang xử lý sản phẩm 396/963
# Đang xử lý sản phẩm 397/963
# Đang xử lý sản phẩm 398/963
# Đang xử lý sản phẩm 399/963
# Đang xử lý sản phẩm 400/963
# Đang xử lý sản phẩm 401/963
# Đang xử lý sản phẩm 402/963
# Đang xử lý sản phẩm 403/963
# Đang xử lý sản phẩm 404/963
# Đang xử lý sản phẩm 405/963
# Đang xử lý sản phẩm 406/963
# Đang xử lý sản phẩm 407/963
# Đang xử lý sản phẩm 408/963
# Đang xử lý sản phẩm 409/963
# Đang xử lý sản phẩm 410/963
# Đang xử lý sản phẩm 411/963
# Đang xử lý sản phẩm 412/963
# Đang xử lý sản phẩm 413/963
# Đang xử lý sản phẩm 414/963
# Đang xử lý sản phẩm 415/963
# Đang xử lý sản phẩm 416/963
# Đang xử lý sản phẩm 417/963
# Đang xử lý sản phẩm 418/963
# Đang xử lý sản phẩm 419/963
# Đang xử lý sản phẩm 420/963
# Đang xử lý sản phẩm 421/963
# Đang xử lý sản phẩm 422/963
# Đang xử lý sản phẩm 423/963
# Đang xử lý sản phẩm 424/963
# Đang xử lý sản phẩm 425/963
# Đang xử lý sản phẩm 426/963
# Đang xử lý sản phẩm 427/963
# Đang xử lý sản phẩm 428/963
# Đang xử lý sản phẩm 429/963
# Đang xử lý sản phẩm 430/963
# Đang xử lý sản phẩm 431/963
# Đang xử lý sản phẩm 432/963
# Đang xử lý sản phẩm 433/963
# Đang xử lý sản phẩm 434/963
# Đang xử lý sản phẩm 435/963
# Đang xử lý sản phẩm 436/963
# Đang xử lý sản phẩm 437/963
# Đang xử lý sản phẩm 438/963
# Đang xử lý sản phẩm 439/963
# Đang xử lý sản phẩm 440/963
# Đang xử lý sản phẩm 441/963
# Đang xử lý sản phẩm 442/963
# Đang xử lý sản phẩm 443/963
# Đang xử lý sản phẩm 444/963
# Đang xử lý sản phẩm 445/963
# Đang xử lý sản phẩm 446/963
# Đang xử lý sản phẩm 447/963
# Đang xử lý sản phẩm 448/963
# Đang xử lý sản phẩm 449/963
# Đang xử lý sản phẩm 450/963
# Đang xử lý sản phẩm 451/963
# Đang xử lý sản phẩm 452/963
# Đang xử lý sản phẩm 453/963
# Đang xử lý sản phẩm 454/963
# Đang xử lý sản phẩm 455/963
# Đang xử lý sản phẩm 456/963
# Đang xử lý sản phẩm 457/963
# Đang xử lý sản phẩm 458/963
# Đang xử lý sản phẩm 459/963
# Đang xử lý sản phẩm 460/963
# Đang xử lý sản phẩm 461/963
# Đang xử lý sản phẩm 462/963
# Đang xử lý sản phẩm 463/963
# Đang xử lý sản phẩm 464/963
# Đang xử lý sản phẩm 465/963
# Đang xử lý sản phẩm 466/963
# Đang xử lý sản phẩm 467/963
# Đang xử lý sản phẩm 468/963
# Đang xử lý sản phẩm 469/963
# Đang xử lý sản phẩm 470/963
# Đang xử lý sản phẩm 471/963
# Đang xử lý sản phẩm 472/963
# Đang xử lý sản phẩm 473/963
# Đang xử lý sản phẩm 474/963
# Đang xử lý sản phẩm 475/963
# Đang xử lý sản phẩm 476/963
# Đang xử lý sản phẩm 477/963
# Đang xử lý sản phẩm 478/963
# Đang xử lý sản phẩm 479/963
# Đang xử lý sản phẩm 480/963
# Đang xử lý sản phẩm 481/963
# Đang xử lý sản phẩm 482/963
# Đang xử lý sản phẩm 483/963
# Đang xử lý sản phẩm 484/963
# Đang xử lý sản phẩm 485/963
# Đang xử lý sản phẩm 486/963
# Đang xử lý sản phẩm 487/963
# Đang xử lý sản phẩm 488/963
# Đang xử lý sản phẩm 489/963
# Đang xử lý sản phẩm 490/963
# Đang xử lý sản phẩm 491/963
# Đang xử lý sản phẩm 492/963
# Đang xử lý sản phẩm 493/963
# Đang xử lý sản phẩm 494/963
# Đang xử lý sản phẩm 495/963
# Đang xử lý sản phẩm 496/963
# Đang xử lý sản phẩm 497/963
# Đang xử lý sản phẩm 498/963
# Đang xử lý sản phẩm 499/963
# Đang xử lý sản phẩm 500/963
# Đang xử lý sản phẩm 501/963
# Đang xử lý sản phẩm 502/963
# Đang xử lý sản phẩm 503/963
# Đang xử lý sản phẩm 504/963
# Đang xử lý sản phẩm 505/963
# Đang xử lý sản phẩm 506/963
# Đang xử lý sản phẩm 507/963
# Đang xử lý sản phẩm 508/963
# Đang xử lý sản phẩm 509/963
# Đang xử lý sản phẩm 510/963
# Đang xử lý sản phẩm 511/963
# Đang xử lý sản phẩm 512/963
# Đang xử lý sản phẩm 513/963
# Đang xử lý sản phẩm 514/963
# Đang xử lý sản phẩm 515/963
# Đang xử lý sản phẩm 516/963
# Đang xử lý sản phẩm 517/963
# Đang xử lý sản phẩm 518/963
# Đang xử lý sản phẩm 519/963
# Đang xử lý sản phẩm 520/963
# Đang xử lý sản phẩm 521/963
# Đang xử lý sản phẩm 522/963
# Đang xử lý sản phẩm 523/963
# Đang xử lý sản phẩm 524/963
# Đang xử lý sản phẩm 525/963
# Đang xử lý sản phẩm 526/963
# Đang xử lý sản phẩm 527/963
# Đang xử lý sản phẩm 528/963
# Đang xử lý sản phẩm 529/963
# Đang xử lý sản phẩm 530/963
# Đang xử lý sản phẩm 531/963
# Đang xử lý sản phẩm 532/963
# Đang xử lý sản phẩm 533/963
# Đang xử lý sản phẩm 534/963
# Đang xử lý sản phẩm 535/963
# Đang xử lý sản phẩm 536/963
# Đang xử lý sản phẩm 537/963
# Đang xử lý sản phẩm 538/963
# Đang xử lý sản phẩm 539/963
# Đang xử lý sản phẩm 540/963
# Đang xử lý sản phẩm 541/963
# Đang xử lý sản phẩm 542/963
# Đang xử lý sản phẩm 543/963
# Đang xử lý sản phẩm 544/963
# Đang xử lý sản phẩm 545/963
# Đang xử lý sản phẩm 546/963
# Đang xử lý sản phẩm 547/963
# Đang xử lý sản phẩm 548/963
# Đang xử lý sản phẩm 549/963
# Đang xử lý sản phẩm 550/963
# Đang xử lý sản phẩm 551/963
# Đang xử lý sản phẩm 552/963
# Đang xử lý sản phẩm 553/963
# Đang xử lý sản phẩm 554/963
# Đang xử lý sản phẩm 555/963
# Đang xử lý sản phẩm 556/963
# Đang xử lý sản phẩm 557/963
# Đang xử lý sản phẩm 558/963
# Đang xử lý sản phẩm 559/963
# Đang xử lý sản phẩm 560/963
# Đang xử lý sản phẩm 561/963
# Đang xử lý sản phẩm 562/963
# Đang xử lý sản phẩm 563/963
# Đang xử lý sản phẩm 564/963
# Đang xử lý sản phẩm 565/963
# Đang xử lý sản phẩm 566/963
# Đang xử lý sản phẩm 567/963
# Đang xử lý sản phẩm 568/963
# Đang xử lý sản phẩm 569/963
# Đang xử lý sản phẩm 570/963
# Đang xử lý sản phẩm 571/963
# Đang xử lý sản phẩm 572/963
# Đang xử lý sản phẩm 573/963
# Đang xử lý sản phẩm 574/963
# Đang xử lý sản phẩm 575/963
# Đang xử lý sản phẩm 576/963
# Đang xử lý sản phẩm 577/963
# Đang xử lý sản phẩm 578/963
# Đang xử lý sản phẩm 579/963
# Đang xử lý sản phẩm 580/963
# Đang xử lý sản phẩm 581/963
# Đang xử lý sản phẩm 582/963
# Đang xử lý sản phẩm 583/963
# Đang xử lý sản phẩm 584/963
# Đang xử lý sản phẩm 585/963
# Đang xử lý sản phẩm 586/963
# Đang xử lý sản phẩm 587/963
# Đang xử lý sản phẩm 588/963
# Đang xử lý sản phẩm 589/963
# Đang xử lý sản phẩm 590/963
# Đang xử lý sản phẩm 591/963
# Đang xử lý sản phẩm 592/963
# Đang xử lý sản phẩm 593/963
# Đang xử lý sản phẩm 594/963
# Đang xử lý sản phẩm 595/963
# Đang xử lý sản phẩm 596/963
# Đang xử lý sản phẩm 597/963
# Đang xử lý sản phẩm 598/963
# Đang xử lý sản phẩm 599/963
# Đang xử lý sản phẩm 600/963
# Đang xử lý sản phẩm 601/963
# Đang xử lý sản phẩm 602/963
# Đang xử lý sản phẩm 603/963
# Đang xử lý sản phẩm 604/963
# Đang xử lý sản phẩm 605/963
# Đang xử lý sản phẩm 606/963
# Đang xử lý sản phẩm 607/963
# Đang xử lý sản phẩm 608/963
# Đang xử lý sản phẩm 609/963
# Đang xử lý sản phẩm 610/963
# Đang xử lý sản phẩm 611/963
# Đang xử lý sản phẩm 612/963
# Đang xử lý sản phẩm 613/963
# Đang xử lý sản phẩm 614/963
# Đang xử lý sản phẩm 615/963
# Đang xử lý sản phẩm 616/963
# Đang xử lý sản phẩm 617/963
# Đang xử lý sản phẩm 618/963
# Đang xử lý sản phẩm 619/963
# Đang xử lý sản phẩm 620/963
# Đang xử lý sản phẩm 621/963
# Đang xử lý sản phẩm 622/963
# Đang xử lý sản phẩm 623/963
# Đang xử lý sản phẩm 624/963
# Đang xử lý sản phẩm 625/963
# Đang xử lý sản phẩm 626/963
# Đang xử lý sản phẩm 627/963
# Đang xử lý sản phẩm 628/963
# Đang xử lý sản phẩm 629/963
# Đang xử lý sản phẩm 630/963
# Đang xử lý sản phẩm 631/963
# Đang xử lý sản phẩm 632/963
# Đang xử lý sản phẩm 633/963
# Đang xử lý sản phẩm 634/963
# Đang xử lý sản phẩm 635/963
# Đang xử lý sản phẩm 636/963
# Đang xử lý sản phẩm 637/963
# Đang xử lý sản phẩm 638/963
# Đang xử lý sản phẩm 639/963
# Đang xử lý sản phẩm 640/963
# Đang xử lý sản phẩm 641/963
# Đang xử lý sản phẩm 642/963
# Đang xử lý sản phẩm 643/963
# Đang xử lý sản phẩm 644/963
# Đang xử lý sản phẩm 645/963
# Đang xử lý sản phẩm 646/963
# Đang xử lý sản phẩm 647/963
# Đang xử lý sản phẩm 648/963
# Đang xử lý sản phẩm 649/963
# Đang xử lý sản phẩm 650/963
# Đang xử lý sản phẩm 651/963
# Đang xử lý sản phẩm 652/963
# Đang xử lý sản phẩm 653/963
# Đang xử lý sản phẩm 654/963
# Đang xử lý sản phẩm 655/963
# Đang xử lý sản phẩm 656/963
# Đang xử lý sản phẩm 657/963
# Đang xử lý sản phẩm 658/963
# Đang xử lý sản phẩm 659/963
# Đang xử lý sản phẩm 660/963
# Đang xử lý sản phẩm 661/963
# Đang xử lý sản phẩm 662/963
# Đang xử lý sản phẩm 663/963
# Đang xử lý sản phẩm 664/963
# Đang xử lý sản phẩm 665/963
# Đang xử lý sản phẩm 666/963
# Đang xử lý sản phẩm 667/963
# Đang xử lý sản phẩm 668/963
# Đang xử lý sản phẩm 669/963
# Đang xử lý sản phẩm 670/963
# Đang xử lý sản phẩm 671/963
# Đang xử lý sản phẩm 672/963
# Đang xử lý sản phẩm 673/963
# Đang xử lý sản phẩm 674/963
# Đang xử lý sản phẩm 675/963
# Đang xử lý sản phẩm 676/963
# Đang xử lý sản phẩm 677/963
# Đang xử lý sản phẩm 678/963
# Đang xử lý sản phẩm 679/963
# Đang xử lý sản phẩm 680/963
# Đang xử lý sản phẩm 681/963
# Đang xử lý sản phẩm 682/963
# Đang xử lý sản phẩm 683/963
# Đang xử lý sản phẩm 684/963
# Đang xử lý sản phẩm 685/963
# Đang xử lý sản phẩm 686/963
# Đang xử lý sản phẩm 687/963
# Đang xử lý sản phẩm 688/963
# Đang xử lý sản phẩm 689/963
# Đang xử lý sản phẩm 690/963
# Đang xử lý sản phẩm 691/963
# Đang xử lý sản phẩm 692/963
# Đang xử lý sản phẩm 693/963
# Đang xử lý sản phẩm 694/963
# Đang xử lý sản phẩm 695/963
# Đang xử lý sản phẩm 696/963
# Đang xử lý sản phẩm 697/963
# Đang xử lý sản phẩm 698/963
# Đang xử lý sản phẩm 699/963
# Đang xử lý sản phẩm 700/963
# Đang xử lý sản phẩm 701/963
# Đang xử lý sản phẩm 702/963
# Đang xử lý sản phẩm 703/963
# Đang xử lý sản phẩm 704/963
# Đang xử lý sản phẩm 705/963
# Đang xử lý sản phẩm 706/963
# Đang xử lý sản phẩm 707/963
# Đang xử lý sản phẩm 708/963
# Đang xử lý sản phẩm 709/963
# Đang xử lý sản phẩm 710/963
# Đang xử lý sản phẩm 711/963
# Đang xử lý sản phẩm 712/963
# Đang xử lý sản phẩm 713/963
# Đang xử lý sản phẩm 714/963
# Đang xử lý sản phẩm 715/963
# Đang xử lý sản phẩm 716/963
# Đang xử lý sản phẩm 717/963
# Đang xử lý sản phẩm 718/963
# Đang xử lý sản phẩm 719/963
# Đang xử lý sản phẩm 720/963
# Đang xử lý sản phẩm 721/963
# Đang xử lý sản phẩm 722/963
# Đang xử lý sản phẩm 723/963
# Đang xử lý sản phẩm 724/963
# Đang xử lý sản phẩm 725/963
# Đang xử lý sản phẩm 726/963
# Đang xử lý sản phẩm 727/963
# Đang xử lý sản phẩm 728/963
# Đang xử lý sản phẩm 729/963
# Đang xử lý sản phẩm 730/963
# Đang xử lý sản phẩm 731/963
# Đang xử lý sản phẩm 732/963
# Đang xử lý sản phẩm 733/963
# Đang xử lý sản phẩm 734/963
# Đang xử lý sản phẩm 735/963
# Đang xử lý sản phẩm 736/963
# Đang xử lý sản phẩm 737/963
# Đang xử lý sản phẩm 738/963
# Đang xử lý sản phẩm 739/963
# Đang xử lý sản phẩm 740/963
# Đang xử lý sản phẩm 741/963
# Đang xử lý sản phẩm 742/963
# Đang xử lý sản phẩm 743/963
# Đang xử lý sản phẩm 744/963
# Đang xử lý sản phẩm 745/963
# Đang xử lý sản phẩm 746/963
# Đang xử lý sản phẩm 747/963
# Đang xử lý sản phẩm 748/963
# Đang xử lý sản phẩm 749/963
# Đang xử lý sản phẩm 750/963
# Đang xử lý sản phẩm 751/963
# Đang xử lý sản phẩm 752/963
# Đang xử lý sản phẩm 753/963
# Đang xử lý sản phẩm 754/963
# Đang xử lý sản phẩm 755/963
# Đang xử lý sản phẩm 756/963
# Đang xử lý sản phẩm 757/963
# Đang xử lý sản phẩm 758/963
# Đang xử lý sản phẩm 759/963
# Đang xử lý sản phẩm 760/963
# Đang xử lý sản phẩm 761/963
# Đang xử lý sản phẩm 762/963
# Đang xử lý sản phẩm 763/963
# Đang xử lý sản phẩm 764/963
# Đang xử lý sản phẩm 765/963
# Đang xử lý sản phẩm 766/963
# Đang xử lý sản phẩm 767/963
# Đang xử lý sản phẩm 768/963
# Đang xử lý sản phẩm 769/963
# Đang xử lý sản phẩm 770/963
# Đang xử lý sản phẩm 771/963
# Đang xử lý sản phẩm 772/963
# Đang xử lý sản phẩm 773/963
# Đang xử lý sản phẩm 774/963
# Đang xử lý sản phẩm 775/963
# Đang xử lý sản phẩm 776/963
# Đang xử lý sản phẩm 777/963
# Đang xử lý sản phẩm 778/963
# Đang xử lý sản phẩm 779/963
# Đang xử lý sản phẩm 780/963
# Đang xử lý sản phẩm 781/963
# Đang xử lý sản phẩm 782/963
# Đang xử lý sản phẩm 783/963
# Đang xử lý sản phẩm 784/963
# Đang xử lý sản phẩm 785/963
# Đang xử lý sản phẩm 786/963
# Đang xử lý sản phẩm 787/963
# Đang xử lý sản phẩm 788/963
# Đang xử lý sản phẩm 789/963
# Đang xử lý sản phẩm 790/963
# Đang xử lý sản phẩm 791/963
# Đang xử lý sản phẩm 792/963
# Đang xử lý sản phẩm 793/963
# Đang xử lý sản phẩm 794/963
# Đang xử lý sản phẩm 795/963
# Đang xử lý sản phẩm 796/963
# Đang xử lý sản phẩm 797/963
# Đang xử lý sản phẩm 798/963
# Đang xử lý sản phẩm 799/963
# Đang xử lý sản phẩm 800/963
# Đang xử lý sản phẩm 801/963
# Đang xử lý sản phẩm 802/963
# Đang xử lý sản phẩm 803/963
# Đang xử lý sản phẩm 804/963
# Đang xử lý sản phẩm 805/963
# Đang xử lý sản phẩm 806/963
# Đang xử lý sản phẩm 807/963
# Đang xử lý sản phẩm 808/963
# Đang xử lý sản phẩm 809/963
# Đang xử lý sản phẩm 810/963
# Đang xử lý sản phẩm 811/963
# Đang xử lý sản phẩm 812/963
# Đang xử lý sản phẩm 813/963
# Đang xử lý sản phẩm 814/963
# Đang xử lý sản phẩm 815/963
# Đang xử lý sản phẩm 816/963
# Đang xử lý sản phẩm 817/963
# Đang xử lý sản phẩm 818/963
# Đang xử lý sản phẩm 819/963
# Đang xử lý sản phẩm 820/963
# Đang xử lý sản phẩm 821/963
# Đang xử lý sản phẩm 822/963
# Đang xử lý sản phẩm 823/963
# Đang xử lý sản phẩm 824/963
# Đang xử lý sản phẩm 825/963
# Đang xử lý sản phẩm 826/963
# Đang xử lý sản phẩm 827/963
# Đang xử lý sản phẩm 828/963
# Đang xử lý sản phẩm 829/963
# Đang xử lý sản phẩm 830/963
# Đang xử lý sản phẩm 831/963
# Đang xử lý sản phẩm 832/963
# Đang xử lý sản phẩm 833/963
# Đang xử lý sản phẩm 834/963
# Đang xử lý sản phẩm 835/963
# Đang xử lý sản phẩm 836/963
# Đang xử lý sản phẩm 837/963
# Đang xử lý sản phẩm 838/963
# Đang xử lý sản phẩm 839/963
# Đang xử lý sản phẩm 840/963
# Đang xử lý sản phẩm 841/963
# Đang xử lý sản phẩm 842/963
# Đang xử lý sản phẩm 843/963
# Đang xử lý sản phẩm 844/963
# Đang xử lý sản phẩm 845/963
# Đang xử lý sản phẩm 846/963
# Đang xử lý sản phẩm 847/963
# Đang xử lý sản phẩm 848/963
# Đang xử lý sản phẩm 849/963
# Đang xử lý sản phẩm 850/963
# Đang xử lý sản phẩm 851/963
# Đang xử lý sản phẩm 852/963
# Đang xử lý sản phẩm 853/963
# Đang xử lý sản phẩm 854/963
# Đang xử lý sản phẩm 855/963
# Đang xử lý sản phẩm 856/963
# Đang xử lý sản phẩm 857/963
# Đang xử lý sản phẩm 858/963
# Đang xử lý sản phẩm 859/963
# Đang xử lý sản phẩm 860/963
# Đang xử lý sản phẩm 861/963
# Đang xử lý sản phẩm 862/963
# Đang xử lý sản phẩm 863/963
# Đang xử lý sản phẩm 864/963
# Đang xử lý sản phẩm 865/963
# Đang xử lý sản phẩm 866/963
# Đang xử lý sản phẩm 867/963
# Đang xử lý sản phẩm 868/963
# Đang xử lý sản phẩm 869/963
# Đang xử lý sản phẩm 870/963
# Đang xử lý sản phẩm 871/963
# Đang xử lý sản phẩm 872/963
# Đang xử lý sản phẩm 873/963
# Đang xử lý sản phẩm 874/963
# Đang xử lý sản phẩm 875/963
# Đang xử lý sản phẩm 876/963
# Đang xử lý sản phẩm 877/963
# Đang xử lý sản phẩm 878/963
# Đang xử lý sản phẩm 879/963
# Đang xử lý sản phẩm 880/963
# Đang xử lý sản phẩm 881/963
# Đang xử lý sản phẩm 882/963
# Đang xử lý sản phẩm 883/963
# Đang xử lý sản phẩm 884/963
# Đang xử lý sản phẩm 885/963
# Đang xử lý sản phẩm 886/963
# Đang xử lý sản phẩm 887/963
# Đang xử lý sản phẩm 888/963
# Đang xử lý sản phẩm 889/963
# Đang xử lý sản phẩm 890/963
# Đang xử lý sản phẩm 891/963
# Đang xử lý sản phẩm 892/963
# Đang xử lý sản phẩm 893/963
# Đang xử lý sản phẩm 894/963
# Đang xử lý sản phẩm 895/963
# Đang xử lý sản phẩm 896/963
# Đang xử lý sản phẩm 897/963
# Đang xử lý sản phẩm 898/963
# Đang xử lý sản phẩm 899/963
# Đang xử lý sản phẩm 900/963
# Đang xử lý sản phẩm 901/963
# Đang xử lý sản phẩm 902/963
# Đang xử lý sản phẩm 903/963
# Đang xử lý sản phẩm 904/963
# Đang xử lý sản phẩm 905/963
# Đang xử lý sản phẩm 906/963
# Đang xử lý sản phẩm 907/963
# Đang xử lý sản phẩm 908/963
# Đang xử lý sản phẩm 909/963
# Đang xử lý sản phẩm 910/963
# Đang xử lý sản phẩm 911/963
# Đang xử lý sản phẩm 912/963
# Đang xử lý sản phẩm 913/963
# Đang xử lý sản phẩm 914/963
# Đang xử lý sản phẩm 915/963
# Đang xử lý sản phẩm 916/963
# Đang xử lý sản phẩm 917/963
# Đang xử lý sản phẩm 918/963
# Đang xử lý sản phẩm 919/963
# Đang xử lý sản phẩm 920/963
# Đang xử lý sản phẩm 921/963
# Đang xử lý sản phẩm 922/963
# Đang xử lý sản phẩm 923/963
# Đang xử lý sản phẩm 924/963
# Đang xử lý sản phẩm 925/963
# Đang xử lý sản phẩm 926/963
# Đang xử lý sản phẩm 927/963
# Đang xử lý sản phẩm 928/963
# Đang xử lý sản phẩm 929/963
# Đang xử lý sản phẩm 930/963
# Đang xử lý sản phẩm 931/963
# Đang xử lý sản phẩm 932/963
# Đang xử lý sản phẩm 933/963
# Đang xử lý sản phẩm 934/963
# Đang xử lý sản phẩm 935/963
# Đang xử lý sản phẩm 936/963
# Đang xử lý sản phẩm 937/963
# Đang xử lý sản phẩm 938/963
# Đang xử lý sản phẩm 939/963
# Đang xử lý sản phẩm 940/963
# Đang xử lý sản phẩm 941/963
# Đang xử lý sản phẩm 942/963
# Đang xử lý sản phẩm 943/963
# Đang xử lý sản phẩm 944/963
# Đang xử lý sản phẩm 945/963
# Đang xử lý sản phẩm 946/963
# Đang xử lý sản phẩm 947/963
# Đang xử lý sản phẩm 948/963
# Đang xử lý sản phẩm 949/963
# Đang xử lý sản phẩm 950/963
# Đang xử lý sản phẩm 951/963
# Đang xử lý sản phẩm 952/963
# Đang xử lý sản phẩm 953/963
# Đang xử lý sản phẩm 954/963
# Đang xử lý sản phẩm 955/963
# Đang xử lý sản phẩm 956/963
# Đang xử lý sản phẩm 957/963
# Đang xử lý sản phẩm 958/963
# Đang xử lý sản phẩm 959/963
# Đang xử lý sản phẩm 960/963
# Đang xử lý sản phẩm 961/963
# Đang xử lý sản phẩm 962/963
# Đang xử lý sản phẩm 963/963
# Xử lý thành công: 963/963 sản phẩm
# Lỗi: 0 sản phẩm
# Dimension của embedding: 1024
# Đã tạo index với 963 sản phẩm
# Kích thước embedding: 1024
# Kích thước embeddings_array: (963, 1024)

# %%
index = faiss.read_index("fashion_clip_concat_index.faiss")
with open("metadata_concat.json", "r", encoding='utf-8') as f:
    metadata = json.load(f)

def search_similar_products(query_text, k=5):
    """Tìm kiếm sản phẩm tương tự với concatenated embeddings"""
    try:
        # Tạo text embedding cho query
        inputs = processor(text=query_text, return_tensors="pt", padding=True, truncation=True, max_length=77).to(device)
        with torch.no_grad():
            query_text_embedding = model.get_text_features(**inputs)
        query_text_embedding = query_text_embedding.cpu().numpy().astype('float32').flatten()

        # Tạo zero vector cho phần image (vì query chỉ có text)
        image_dim = 512  # FashionCLIP embedding dimension
        zero_image_embedding = np.zeros(image_dim, dtype='float32')

        # Concatenate zero image embedding với text embedding
        query_embedding = np.concatenate([zero_image_embedding, query_text_embedding])

        # Chuẩn hóa và tìm kiếm
        faiss.normalize_L2(query_embedding.reshape(1, -1))
        scores, indices = index.search(query_embedding.reshape(1, -1), k)

        # Trả về kết quả
        results = []
        for i, idx in enumerate(indices[0]):
            results.append({
                'score': scores[0][i],
                'metadata': metadata[idx]
            })
        return results
    except Exception as e:
        print(f"Lỗi khi tìm kiếm: {str(e)}")
        return []

def search_similar_products_with_image(query_image_url, k=5):
    """Tìm kiếm sản phẩm tương tự với ảnh query"""
    try:
        # Tạo image embedding cho query
        query_image_embedding = get_image_embedding(query_image_url)
        if query_image_embedding is None:
            return []

        # Tạo zero vector cho phần text (vì query chỉ có ảnh)
        text_dim = 512  # FashionCLIP embedding dimension
        zero_text_embedding = np.zeros(text_dim, dtype='float32')

        # Concatenate image embedding với zero text embedding
        query_embedding = np.concatenate([query_image_embedding, zero_text_embedding])

        # Chuẩn hóa và tìm kiếm
        faiss.normalize_L2(query_embedding.reshape(1, -1))
        scores, indices = index.search(query_embedding.reshape(1, -1), k)

        # Trả về kết quả
        results = []
        for i, idx in enumerate(indices[0]):
            results.append({
                'score': scores[0][i],
                'metadata': metadata[idx]
            })
        return results
    except Exception as e:
        print(f"Lỗi khi tìm kiếm bằng ảnh: {str(e)}")
        return []

# %%
def search_similar_products_with_combined(query_text=None, query_image_url=None, k=5, text_weight=0.5, image_weight=0.5):
    """
    Tìm kiếm sản phẩm tương tự với cả text và image embedding

    Args:
        query_text (str, optional): Văn bản mô tả sản phẩm cần tìm
        query_image_url (str, optional): URL ảnh sản phẩm cần tìm
        k (int): Số lượng kết quả trả về
        text_weight (float): Trọng số cho text embedding (0-1)
        image_weight (float): Trọng số cho image embedding (0-1)

    Returns:
        list: Danh sách sản phẩm tương tự với score và metadata
    """
    try:
        image_dim = 512  # FashionCLIP embedding dimension
        text_dim = 512

        # Khởi tạo embeddings
        image_embedding = np.zeros(image_dim, dtype='float32')
        text_embedding = np.zeros(text_dim, dtype='float32')

        # Tạo image embedding nếu có query_image_url
        if query_image_url is not None:
            image_embedding = get_image_embedding(query_image_url)
            if image_embedding is None:
                print("Không thể tạo image embedding, sử dụng zero vector")
                image_embedding = np.zeros(image_dim, dtype='float32')
            else:
                # Áp dụng trọng số cho image embedding
                image_embedding = image_embedding * image_weight

        # Tạo text embedding nếu có query_text
        if query_text is not None:
            inputs = processor(
                text=query_text,
                return_tensors="pt",
                padding=True,
                truncation=True,
                max_length=77
            ).to(device)

            with torch.no_grad():
                text_embedding = model.get_text_features(**inputs)

            text_embedding = text_embedding.cpu().numpy().astype('float32').flatten()
            # Áp dụng trọng số cho text embedding
            text_embedding = text_embedding * text_weight

        # Kiểm tra nếu không có query nào
        if query_text is None and query_image_url is None:
            print("Cần cung cấp ít nhất một trong hai: query_text hoặc query_image_url")
            return []

        # Concatenate image và text embeddings
        query_embedding = np.concatenate([image_embedding, text_embedding])

        # Chuẩn hóa embedding
        faiss.normalize_L2(query_embedding.reshape(1, -1))

        # Tìm kiếm trong FAISS index
        scores, indices = index.search(query_embedding.reshape(1, -1), k)

        # Tạo kết quả
        results = []
        for i, idx in enumerate(indices[0]):
            results.append({
                'score': float(scores[0][i]),
                'metadata': metadata[idx],
                'rank': i + 1
            })

        return results

    except Exception as e:
        print(f"Lỗi khi tìm kiếm kết hợp: {str(e)}")
        import traceback
        traceback.print_exc()
        return []

# %%
print("=== Tìm kiếm bằng text ===")
results = search_similar_products("áo thun nam thể thao màu nâu ngắn tay mùa đông", k=3)
for result in results:
    print(f"Score: {result['score']:.4f}")
    print(f"Title: {result['metadata']['pdp_title']}")
    print(f"Price: {result['metadata']['price_sp']}")
    print(f" URL: {result['metadata']['pdp_url']}")
    print("---")
# Out:
# === Tìm kiếm bằng text ===
# Score: 0.5984
# Title: Áo Thun Bóng Rổ Dài Tay Nhanh Khô Cho Nam Áo Thun Thể Thao Thường Ngày Cổ Đứng Áo Thun Thể Thao Chạy Bộ Ngoài Trời Áo Thun Thể Thao
# Price: 73710
#  URL: https://www.lazada.vn/products/pdp-i3063700688.html
# ---
# Score: 0.5959
# Title: Quần áo đi câu bảo vệ khỏi ánh mặt trời của đàn ông ngoài trời dài tay làm khô nhanh chống tia cực tím quần áo đi câu đi câu mới
# Price: 169464
#  URL: https://www.lazada.vn/products/pdp-i2740862607.html
# ---
# Score: 0.5946
# Title: Quần Dài Nam Màu Trắng Mùa Hè Mỏng Thời Trang Lụa Băng Quần Dài Ống Rộng Ống Đứng Rộng Rãi Quần Dài Thường Ngày
# Price: 116000
#  URL: https://www.lazada.vn/products/pdp-i1974727487.html
# ---

# %%
# Thay thế bằng URL ảnh thực tế
results = search_similar_products_with_image("https://img.lazcdn.com/g/ff/kf/S26d1303cc3684401a0acf0762645efb9n.jpg_720x720q80.jpg_.webp", k=3)
for result in results:
    print(f"Score: {result['score']:.4f}")
    print(f"Title: {result['metadata']['pdp_title']}")
    print(f" URL: {result['metadata']['pdp_url']}")
    print("---")
# Out:
# Score: 0.7079
# Title: [HCM]ÁO THUN NAM CỔ BẺ TAY NGẮN 5 MÀU ĐƠN GIÃN SANG TRỌNG DỄ MẶC VỚI NHIỀU TRANG PHỤC 01
#  URL: https://www.lazada.vn/products/pdp-i254832834.html
# ---
# Score: 0.6969
# Title: [ 6 MÀU ] ÁO THUN NAM VẢI CÁ SẤU POLY DÀY MƯỢT MÁT ÁO POLO TAY NGẮN CỔ PHỐI MÀU BASIC 01
#  URL: https://www.lazada.vn/products/pdp-i276994224.html
# ---
# Score: 0.6894
# Title: CÓ 3 MÀU LỰA CHỌN _ ÁO THUN NAM CÓ TÀU TAY NGẮN ĐƠN GIÃN THANH LỊCH SANG TRỌNG DỄ MẶC MÃ 12
#  URL: https://www.lazada.vn/products/pdp-i2271124453.html
# ---

# %%
# 3. Tìm kiếm kết hợp cả text và image
results = search_similar_products_with_combined(
    query_text="blue t-shirt",
    query_image_url="https://img.lazcdn.com/g/ff/kf/S26d1303cc3684401a0acf0762645efb9n.jpg_720x720q80.jpg_.webp",
    k=5,
    text_weight=0.6,
    image_weight=0.4
)
for result in results:
    print(f"Score: {result['score']:.4f}")
    print(f"Title: {result['metadata']['pdp_title']}")
    print(f"Price: {result['metadata']['price_sp']}")
    print(f" URL: {result['metadata']['pdp_url']}")
    print("---")
# Out:
# Score: 0.7223
# Title: [ 6 MÀU ] ÁO THUN NAM VẢI CÁ SẤU POLY DÀY MƯỢT MÁT ÁO POLO TAY NGẮN CỔ PHỐI MÀU BASIC 01
# Price: 78000
#  URL: https://www.lazada.vn/products/pdp-i276994224.html
# ---
# Score: 0.6915
# Title: Áo đũi nam cộc tay cổ bẻ full cúc
# Price: 99000
#  URL: https://www.lazada.vn/products/pdp-i2369924826.html
# ---
# Score: 0.6714
# Title: [HCM]ÁO THUN NAM CỔ BẺ TAY NGẮN 5 MÀU ĐƠN GIÃN SANG TRỌNG DỄ MẶC VỚI NHIỀU TRANG PHỤC 01
# Price: 78000
#  URL: https://www.lazada.vn/products/pdp-i254832834.html
# ---
# Score: 0.6638
# Title: áo dài tay nam thu đông đẹp có size to tới 95kg
# Price: 115000
#  URL: https://www.lazada.vn/products/pdp-i3177323277.html
# ---
# Score: 0.6612
# Title: CÓ 3 MÀU LỰA CHỌN _ ÁO THUN NAM CÓ TÀU TAY NGẮN ĐƠN GIÃN THANH LỊCH SANG TRỌNG DỄ MẶC MÃ 12
# Price: 78000
#  URL: https://www.lazada.vn/products/pdp-i2271124453.html
# ---
